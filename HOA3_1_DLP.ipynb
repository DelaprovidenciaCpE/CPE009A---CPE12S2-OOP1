# %% [markdown]
# <a href="https://colab.research.google.com/github/DelaprovidenciaCpE/CPE009A---CPE12S2-OOP1/blob/main/HOA3_1_DLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lists

# %%
#
numberList = [5,4,2,1,3]
print(len(numberList))
# Out:
# 5

# %%
print(len(numberList[1]))

# %%
print(numberList[0])
# Out:
# 5

# %%
print(numberList[2])
# Out:
# 2

# %%
print(numberList[3])

# %%
print(numberList[4])
# Out:
# 3

# %%
print(numberList[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2395/3532079887.py in <cell line: 0>()
# ----> 1 print(numberList[5])
#
# IndexError: list index out of range

# %%
print(numberList[-1])
# Out:
# 3

# %%
print(numberList[-2])
# Out:
# 1

# %%
print(numberList[-3])
# Out:
# 2

# %%
print(numberList[-4])
# Out:
# 4

# %%
print(numberList[-5])
# Out:
# 5

# %%
print(numberList[-6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2395/1321896185.py in <cell line: 0>()
# ----> 1 print(numberList[-6])
#
# IndexError: list index out of range
