# %% [markdown]
# <a href="https://colab.research.google.com/github/DelaprovidenciaCpE/CPE009A---CPE12S2-OOP1/blob/main/Hands_on_Activity_1_1_Literals%2C_Operators%2C_and_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assigning variable of different data type in Python**

# %%
value=5
print(value)
# Out:
# 5

# %%
type(value)
# Out:
# int

# %%
value = 5.0
print(value)
# Out:
# 5.0

# %%
type(value)
# Out:
# float

# %% [markdown]
# A.

# %%
value=2+3j
print(value)
# Out:
# (2+3j)

# %%
type (value)
# Out:
# complex

# %% [markdown]
# B.

# %%
value='Hello World'
print(value)
# Out:
# Hello World

# %%
type (value)
# Out:
# str

# %% [markdown]
# C.

# %%
value="Hello World"
print(value)
# Out:
# Hello World

# %%
type (value)
# Out:
# str

# %% [markdown]
# D.

# %%
value=True
print(value)
# Out:
# True

# %%
type(value)
# Out:
# bool

# %% [markdown]
# E.

# %%
value=False
print(value)
# Out:
# False

# %%
type(value)
# Out:
# bool

# %% [markdown]
# F.

# %%
value=[1,2,3,4,5]
print(value)
# Out:
# [1, 2, 3, 4, 5]

# %%
type(value)
# Out:
# list

# %% [markdown]
# G.

# %%
value=(1,2,3,4,5)
print(value)
# Out:
# (1, 2, 3, 4, 5)

# %%
type(value)
# Out:
# tuple

# %% [markdown]
# H.

# %%
value={'name': "Dane Matthew F. Dela Providencia"}
print(value)
# Out:
# {'name': 'Dane Matthew F. Dela Providencia'}

# %%
type(value)
# Out:
# dict

# %% [markdown]
# I.

# %%
value=None
print(value)
# Out:
# None

# %%
type(value)
# Out:
# NoneType

# %%
value=5

# %%
value=-6

# %% [markdown]
# # **Performing Operation with Python**

# %%
print(value+value2)
# Out:
# -1

# %% [markdown]
# A.

# %%
value, value2 =5.0,6

# %%
print(value+value2)
# Out:
# 11.0

# %% [markdown]
# B.

# %%
value, value2=-5, 6.1

# %%
print (value+value2)
# Out:
# 1.0999999999999996

# %% [markdown]
# C.

# %%
value, value2= "Hello ", 'World'

# %%
print (value + value2)
# Out:
# Hello World

# %% [markdown]
# D.

# %%
value, value2= [1,2,3], [4,5,6]

# %%
print (value+value2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# E.

# %%
value, value2 = (1,2,3), (4,5,6)

# %%
print(value+value2)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# F.

# %%
value, value2 = {"name":"Royce"}, {"age": 2}

# %%
print(value,value2)
# Out:
# {'name': 'Royce'} {'age': 2}

# %% [markdown]
# # 3. **Using valu, value2 = 30, 4. Type the commands:**

# %%
value, value2= 30, 4

# %%
print(value*value2)
# Out:
# 120

# %% [markdown]
# B.

# %%
print(value2**2)
# Out:
# 16

# %% [markdown]
# C.

# %%
print(value2**3)
# Out:
# 64

# %% [markdown]
# D.

# %%
print(value*value2+value2**2+1)
# Out:
# 137

# %% [markdown]
# E.

# %%
print(value/value2)
# Out:
# 7.5

# %% [markdown]
# F.

# %%
print(value%value2)
# Out:
# 2

# %% [markdown]
# # **Receiving Input Data Using Python**

# %%
input("NAME: ")
# Out:
# NAME: Dane
# 'Dane'

# %% [markdown]
# ## Assigning Input Data to a Variable

# %%
name=input("Enter Name:" )
weight=input("Enter Weight(kg): ")
height=input("Enter Height(m): ")
bmi = float(weight)/float(height)**2
# Out:
# Enter Name:Dane
# Enter Weight(kg): 54
# Enter Height(m): 1.6509

# %%
print(name)
print(weight)
print(height)
print(bmi)
# Out:
# Dane
# 54
# 1.6509
# 19.8130905683778

# %% [markdown]
# ## Supplementary Activity

# %% [markdown]
# 1.

# %%
base = float(input("Enter the Base of a triangle: "))
height = float(input("Enter the Height of a triangle: "))
area = 1/2 * base * height

print("The Area of a Triangle is: ", area)
# Out:
# Enter the Base of a triangle: 5
# Enter the Height of a triangle: 6
# The Area of a Triangle is:  15.0

# %% [markdown]
# 2.

# %%
celcius = float(input("Enter the temperature in celcius: "))
fahrenheit = (celcius * 9/5) + 32

print("The temperature in fahrenheit is: ", fahrenheit)
# Out:
# Enter the temperature in celcius: 0
# The temperature in fahrenheit is:  32.0

# %% [markdown]
# 3.

# %%
x1= float(input("Enter the x - coordinate of the first point: "))
y1= float(input("Enter the y - coordinate of the first point: "))
x2 = float(input("Enter the x - coordinate of the second point: "))
y2 = float(input("Enter the y - coordinate of the second point: "))

d = ( (x2-x1)**2 + (y2-y1)**2 ) **(1/2)
print(d)
