# %% [markdown]
# <a href="https://colab.research.google.com/github/DelaprovidenciaCpE/CPE009A---CPE12S2-OOP1/blob/main/MIDTERM_DLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
asterisk = 5
for i in range(0,asterisk):
    for j in range(0, i + 1):
        print("*", end='')
    print("\r")
# Out:
# *
# **
# ***
# ****
# *****
